# %% [markdown]
# # Probando Polylla con vem
#
# Primero se definen las funciones a probar

# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
from mpl_toolkits.axes_grid1 import make_axes_locatable
from vem import vem, plot_solution

def square_domain_boundary_condition(points):
    x = points[:, 0]
    y = points[:, 1]

    g = (1 - x) * y * np.sin(np.pi * x)

    return g

def square_domain_rhs(point):
    x = point[0]
    y = point[1]

    f = 15 * np.sin(np.pi * x) * np.sin(np.pi * y)
    return f

def test_domain_rhs(point):
    return 0

def test_boundary_condition(points):
    x = points[:, 0]
    y = points[:, 1]

    g = x + y
    return g

def test2_domain_rhs(point):
    return 0

def test2_boundary_condition(points):
    x = points[:, 0]
    y = points[:, 1]

    g = np.exp(x)*np.sin(y)
    return g
    

# pa pruebas
def harmonic_boundary_condition(points):
    x = points[:, 0]
    y = points[:, 1]

    g = np.sin(4*np.pi * x) + np.sin(4*np.pi * y)
    return g


def harmonic_rhs(point):
    x = point[0]
    y = point[1]

    f = (x**2 + y**2)*100
    return f

domain_rhs = test2_domain_rhs
domain_boundary_condition = test2_boundary_condition

# %% [markdown]
# Se prueban las funciones con las distintas Polyllas

# %%
folder = "polyllaMeshes/"
#NumPoints = 10
NumPoints = 500
#NumPoints = 2500
#NumPoints = 5000

# %%
#uniform
u = vem(folder + str(NumPoints) + "uniform.polylla.mat", domain_rhs, domain_boundary_condition)
plot_solution(folder + str(NumPoints) + "uniform.polylla.mat", u)
# Out:
# min of norms: 0.8660254037844386
# ids: []
# coords: []

# %%
#semiUniform
u = vem(folder + str(NumPoints) + "semiUniform.polylla.mat", domain_rhs, domain_boundary_condition)
plot_solution(folder + str(NumPoints) + "semiUniform.polylla.mat", u)
# Out:
# d:\Dropbox\Doctorado\Investigacion\VirtualElementMethods\vem.py:78: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   elements = np.array([i[0].reshape(-1) - 1 for i in mesh['elements']])
# min of norms: 0.9414949462508209
# ids: []
# coords: []
# d:\Dropbox\Doctorado\Investigacion\VirtualElementMethods\vem.py:204: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   elements = np.array([i[0].reshape(-1) - 1 for i in mesh['elements']])

# %%
# Poisson
u = vem(folder + str(NumPoints) + "poisson.polylla.mat", domain_rhs, domain_boundary_condition)
plot_solution(folder + str(NumPoints) + "poisson.polylla.mat", u)
# Out:
# min of norms: 0.0
# ids: [536 538]
# coords: [[1. 1.]
#  [1. 0.]]
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In [5], line 2
#       1 # Poisson
# ----> 2 u = vem(folder + str(NumPoints) + "poisson.polylla.mat", domain_rhs, domain_boundary_condition)
#       3 plot_solution(folder + str(NumPoints) + "poisson.polylla.mat", u)
#
# File d:\Dropbox\Doctorado\Investigacion\VirtualElementMethods\vem.py:193, in vem(mesh_file, rhs, boundary_condition)
#     189 print(f'coords: {coords}')
#     191 #print(K_II, F[internal_dofs])
#     192 #print(np.linalg.eigvals(K_II))
# --> 193 u[internal_dofs] = np.linalg.solve(K_II, F[internal_dofs])
#     194 u[boundary] = boundary_vals
#     196 return u
#
# File <__array_function__ internals>:180, in solve(*args, **kwargs)
#
# ...

# %%
#random
u = vem( folder + str(NumPoints) +  "random.polylla.mat", domain_rhs, domain_boundary_condition)
plot_solution(folder + str(NumPoints) + "poisson.polylla.mat", u)
# Out:
# min of norms: 1.7506916724274624
# ids: []
# coords: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [6], line 3
#       1 #random
#       2 u = vem( folder + str(NumPoints) +  "random.polylla.mat", domain_rhs, domain_boundary_condition)
# ----> 3 plot_solution(folder + str(NumPoints) + "poisson.polylla.mat", u)
#
# File d:\Dropbox\Doctorado\Investigacion\VirtualElementMethods\vem.py:216, in plot_solution(mesh_file, u, save, plot_name)
#     213 xi = np.linspace(min(x) - 0.01, max(x) + 0.001, 100)
#     214 yi = np.linspace(min(y) - 0.01, max(y) + 0.001, 100)
# --> 216 zi = griddata((x, y), v, (xi[None, :], yi[:, None]), method='linear')
#     217 for i in range(len(elements)):
#     219     for j in range(len(elements[i])):
#
# ...

# %%
u = vem("testVEMXeviEloi.mat", domain_rhs, domain_boundary_condition)
plot_solution("testVEMXeviEloi.mat", u)
